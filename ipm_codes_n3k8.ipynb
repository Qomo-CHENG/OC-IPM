# %% [markdown]
# # IV. Linear codes for Inner Product Masking
#
# ### $n=3$ shares, $\ell=8$ bits

# %% [markdown]
# Parameters:
#
# - $Z=(X + L_2Y_2 + L_3Y_3, Y_2, Y_3)=X\mathbf{G} + Y\mathbf{H}$ where $X, Y=(Y_2, Y_3)$ and $Z$ are the sensitive variable, a mask and the protected variable, respectively. $\mathbf{G} = [1, 0, 0]$ and $\mathbf{H} = [[L_2, 1, 0], [L_3, 0, 1]]$ are two generator matrices of codes $\mathcal{C}$ and $\mathcal{D}$, resp.
# - $L_2, L_3\in \mathbb{F}_{2^\ell}\backslash\{0\}$, thus there are 255*255=65025 linear codes for IPM. In order to save spaces, we take $L_2\leq L_3$ and $L_2=\alpha^i$ where $i\in \{0, 1, \ldots, 255\}$ (note that $\alpha^0=\alpha^{255}$ in $\mathbb{F}_{2^8}$). As a consequence, we have 32896 entries and one more for BKLC codes with parameter [24, 8, 8].
# - Each element over $\mathbb{F}_{2^\ell}$ can be denoted as $\alpha^i$ where $i\in\{0, 1, \ldots, 254\}$
# - $\mathbf{H}^\perp = [1, L_2, L_3]$ is the generator matirx of dual code $\mathcal{D}^\perp$

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import pandas as pd # Pandas for tables
from IPython.display import Latex
from IPython.display import HTML

# %%
def read_f(file_name):
    """Reading weight enumerators."""
    with open(file_name, 'r') as fp:
        wd = fp.read().split("]\n")[:-1] # "\n"
        wd = np.array([list(map(int, re.findall(r"\d+", elem))) for elem in wd])
        
    return wd

def find_ind(i):
    """Generating index of L_2 and L_3"""
    ii = 256*(256+1)/2-i-1
    kk = np.floor((np.sqrt(8*ii+1)-1)/2)
    irow = int(256-1-kk)
    icol = int(i-256*(256+1)/2 + (256-irow)*(257-irow)/2 +irow)
    
    return irow, icol

# %% [markdown]
# ## 1. Loading all weight enumerators

# %%
wd = read_f("weight_distrib_n3k8.txt") # Weight distribution

# print(wd.shape) # 226 entries: 225 for IPM codes and one for BKLC codes

# %% [markdown]
# ### 1.1 Generating values

# %%
alpha_all = np.array(['$\\alpha^{%d}$'%i for i in np.arange(256)])
d_all = np.zeros(len(wd))
B_all = np.zeros(len(wd))
L_2 = np.zeros(len(wd), dtype=int)
L_3 = np.zeros(len(wd), dtype=int)
for i in range(len(wd)):
    d_all[i] = wd[i][2]
    B_all[i] = wd[i][3]
    if i<len(wd)-1:
        irow, icol = find_ind(i)
        L_2[i] = irow
        L_3[i] = icol

# %% [markdown]
# ### 1.2 Defining styles of dataframe

# %%
# Set properties for th, td and caption elements in dataframe
th_props = [('font-size', '14px'), ('text-align', 'left'), ('font-weight', 'bold'), ('background-color', '#E0E0E0')]
td_props = [('font-size', '13px'), ('text-align', 'left'), ('min-width', '80px')]
cp_props = [('font-size', '16px'), ('text-align', 'center')]
# Set table styles
styles = [dict(selector="th", props=th_props), dict(selector="td", props=td_props), dict(selector="caption", props=cp_props)]
cm_1 = sns.light_palette("red", as_cmap=True)
cm_2 = sns.light_palette("purple", as_cmap=True, reverse=True)

# %%
#df = pd.DataFrame({'$L_2$': alpha_all[L_2[:-1]], '$L_3$': alpha_all[L_3[:-1]], '$d_{\mathcal{D}}^\perp$': d_all[:-1], 
#                   '$B_{d_{\mathcal{D}}^\perp}$': B_all[:-1], 'Weight Enumerators': wd[:-1]})

pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.width', 400)

# %% [markdown]
# <span style="color:red"> **We omit the complete table I here to avoid wasting of spaces. Hereafter, we only show all codes with maximized $d_{\mathcal{D}}^\perp=8$.**</span>

# %% [markdown]
# ## 2. Optimal linear codes for IPM

# %% [markdown]
# ### 2.1 Linear codes with $d_{\mathcal{D}}^\perp=8$
#
# We focus on the the linear codes with greater $d_{\mathcal{D}}^\perp$, which are better in the sense of side-channel resistance (from our paper).

# %%
# Finding the indices of d_C=8
d_index = []
d_index_L2 = []
d_index_L3 = []
d_C = 8
for i in range(len(wd)-1):
    if wd[i][2] == d_C:
        d_index.append(i)
        irow, icol = find_ind(i)
        d_index_L2.append(irow)
        d_index_L3.append(icol)

#d_index = np.array(d_index)

# %%
print(len(d_index))
# Out:
# 114

# %%
def highlight(s, threshold, column):
    is_min = pd.Series(data=False, index=s.index)
    is_min[column] = (s.loc[column] <= threshold)
    return ['background-color: gold' if is_min.any() else '' for v in is_min]

# %%
df_4 = pd.DataFrame({'$L_2$': np.array(alpha_all)[d_index_L2], '$L_3$': np.array(alpha_all)[d_index_L3], '$d_{\mathcal{D}}^\perp$': 
                     d_all[d_index], '$B_{d_{\mathcal{D}}^\perp}$': B_all[d_index], 'Weight Enumerators': wd[d_index]})
df_4 = df_4.sort_values(by=['$B_{d_{\mathcal{D}}^\perp}$'], ascending=True)

(df_4.style
    .apply(highlight, threshold=7, column=['$B_{d_{\mathcal{D}}^\perp}$'], axis=1)
    .background_gradient(cmap=cm_2, subset=['$B_{d_{\mathcal{D}}^\perp}$' ])
    .set_caption('Tab. II Linear codes for IPM with $d_{\mathcal{D}}^\perp=8$.')
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_ec90d482_42fd_11ea_834b_144f8ad8692b th {
#           font-size: 14px;
#           text-align: left;
#           font-weight: bold;
#           background-color: #E0E0E0;
#     }    #T_ec90d482_42fd_11ea_834b_144f8ad8692b td {
#           font-size: 13px;
#           text-align: left;
#           min-width: 80px;
#     }    #T_ec90d482_42fd_11ea_834b_144f8ad8692b caption {
#           font-size: 16px;
#           text-align: center;
#     }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow0_col0 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow0_col1 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow0_col2 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow0_col3 {
#             background-color:  gold;
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow0_col4 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow1_col0 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow1_col1 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow1_col2 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow1_col3 {
#             background-color:  gold;
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow1_col4 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow2_col0 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow2_col1 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow2_col2 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow2_col3 {
#             background-color:  gold;
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow2_col4 {
#             background-color:  gold;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow3_col3 {
#             : ;
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow4_col3 {
#             : ;
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow5_col3 {
#             : ;
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow6_col3 {
#             : ;
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow7_col3 {
#             : ;
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow8_col3 {
#             : ;
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow9_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow10_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow11_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow12_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow13_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow14_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow15_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow16_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow17_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow18_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow19_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow20_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow21_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow22_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow23_col3 {
#             : ;
#             background-color:  #a746a7;
#             color:  #f1f1f1;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow24_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow25_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow26_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow27_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow28_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow29_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow30_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow31_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow32_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow33_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow34_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow35_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow36_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow37_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow38_col3 {
#             : ;
#             background-color:  #b158b1;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow39_col3 {
#             : ;
#             background-color:  #bb6abb;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow40_col3 {
#             : ;
#             background-color:  #bb6abb;
#             color:  #000000;
#         }    #T_ec90d482_42fd_11ea_834b_144f8ad8692brow41_col3 {
#             : ;
#             background-color:  #bb6abb;
#             color:

# %% [markdown]
# ### 2.2 Optimal codes for IPM
#
# As shown in our paper, the codes satifying two conditions are optimal:
#
# - Maximizing $d_{\mathcal{D}}^\perp$, here $\max\{d_{\mathcal{D}}^\perp\} = 8$
# - Minimizing $B_{d_{\mathcal{D}}^\perp}$, here $\min\{B_{d_{\mathcal{D}}^\perp}\} = 7$
#
# Note that we use two leakage detection metrics **SNR** (signal-to-noise ratio) and **MI** (mutual information), and one leakage exploitation metric **SR** (success rate) to assess the side-channel resistance of IPM with different codes.

# %% [markdown]
# As a result of Tab. II, we conclude that the optimal codes for IPM are genetated by $\mathbf{H}=[[L_2, 1, 0], [L_3, 0, 1]]$ where $(L_2, L_3)\in\{(\alpha^{18}, \alpha^{183}), (\alpha^{72}, \alpha^{90}), (\alpha^{165}, \alpha^{237})\}$. Note that by exchanging $L_2$ and $L_3$, the codes are still optimal (we omit the equivalent codes to save spaces here).

# %% [markdown]
# ### 2.3 BKLC code with parameter $[24, 8, 8]$
#
# BKLC is the short of Best Known Linear Code. Note that the code $[24, 8, 8]$ is unique.

# %%
bklc_index = [-1]
cm_3 = sns.light_palette("red", as_cmap=True, reverse=True)
df_bklc = pd.DataFrame({'$L_2$': ['  --'], '$L_3$': ['  --'], '$d_{\mathcal{D}}^\perp$': d_all[-1], '$B_{d_{\mathcal{D}}^\perp}$': 
                        B_all[-1], 'Weight Enumerators': wd[bklc_index]})

(df_bklc.style
    .background_gradient(cmap=cm_3, subset=['$d_{\mathcal{D}}^\perp$', '$B_{d_{\mathcal{D}}^\perp}$'])
    .set_caption('Tab. III A BKLC code for IPM with $d_{\mathcal{D}}^\perp=8$.')
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_eff8295e_42fd_11ea_a69a_144f8ad8692b th {
#           font-size: 14px;
#           text-align: left;
#           font-weight: bold;
#           background-color: #E0E0E0;
#     }    #T_eff8295e_42fd_11ea_a69a_144f8ad8692b td {
#           font-size: 13px;
#           text-align: left;
#           min-width: 80px;
#     }    #T_eff8295e_42fd_11ea_a69a_144f8ad8692b caption {
#           font-size: 16px;
#           text-align: center;
#     }    #T_eff8295e_42fd_11ea_a69a_144f8ad8692brow0_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_eff8295e_42fd_11ea_a69a_144f8ad8692brow0_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_eff8295e_42fd_11ea_a69a_144f8ad8692b" ><caption>Tab. III A BKLC code for IPM with $d_{\mathcal{D}}^\perp=8$.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >$L_2$</th>        <th class="col_heading level0 col1" >$L_3$</th>        <th class="col_heading level0 col2" >$d_{\mathcal{D}}^\perp$</th>        <th class="col_heading level0 col3" >$B_{d_{\mathcal{D}}^\perp}$</th>        <th class="col_heading level0 col4" >Weight Enumerators</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eff8295e_42fd_11ea_a69a_144f8ad8692blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eff8295e_42fd_11ea_a69a_144f8ad8692brow0_col0" class="data row0 col0" >  --</td>
#                         <td id="T_eff8295e_42fd_11ea_a69a_144f8ad8692brow0_col1" class="data row0 col1" >  --</td>
#                         <td id="T_eff8295e_42fd_11ea_a69a_144f8ad8692brow0_col2" class="data row0 col2" >8</td>
#                         <td id="T_eff8295e_42fd_11ea_a69a_144f8ad8692brow0_col3" class="data row0 col3" >130</td>
#                         <td id="T_eff8295e_42fd_11ea_a69a_144f8ad8692brow0_col4" class="data row0 col4" >[0, 1, 8, 130, 12, 120, 16, 5]</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# We can see that this BKLC code is worse than all linear codes with $d_{\mathcal{D}}^\perp=8$ in IPM, since the $B_{d_{\mathcal{D}}^\perp}$ in this BKLC code is much greater than in IPM codes. It is interesting to notice that the BKLC code $[24, 8, 8]$ cannot be generated by any $\mathbf{H}^\perp=[1, L_2, L_3]$ where $L_2, L_3 \in \mathbb{F}_{2^8}\backslash\{0\}$.
